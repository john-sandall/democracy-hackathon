# %%
import numpy as np
import cv2
import pytesseract
import pandas as pd

from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
img = Image.open("form.jpg")
draw = ImageDraw.Draw(img)
# font = ImageFont.truetype(<font-file>, <font-size>)
font = ImageFont.truetype("arial.ttf", 24)

# %%
# draw.text((x, y),"Sample Text",(r,g,b))

#First name(s) in full
draw.text((150, 695),"X",(0,0,0),font=font) 

#Surname
draw.text((150, 580),"X",(0,0,0),font=font) 

#home_address
draw.text((150, 810),"X",(0,0,0),font=font) 
draw.text((150, 870),"X",(0,0,0),font=font) 
draw.text((150, 930),"X",(0,0,0),font=font)

#postcode
draw.text((550, 980),"X",(0,0,0),font=font)

#Telephone
draw.text((150, 1095),"X",(0,0,0),font=font) 

#Email
draw.text((150, 1210),"X",(0,0,0),font=font) 

#Until further notice
draw.text((133, 1600),"X",(0,0,0),font=font) 

#Address for ballot paper
draw.text((950, 620),"X",(0,0,0),font=font) 
draw.text((950, 680),"X",(0,0,0),font=font)
draw.text((950, 730),"X",(0,0,0),font=font)

#Postcode
draw.text((1430, 790),"X",(0,0,0),font=font)

#Reason 
draw.text((950, 930),"X",(0,0,0),font=font)
draw.text((950, 990),"X",(0,0,0),font=font)

#Date of birth
#day
draw.text((930, 1450),"X",(0,0,0),font=font) 
draw.text((995, 1450),"X",(0,0,0),font=font)
#month
draw.text((1100, 1450),"X",(0,0,0),font=font) 
draw.text((1165, 1450),"X",(0,0,0),font=font) 
#year
draw.text((1270, 1450),"X",(0,0,0),font=font)
draw.text((1340, 1450),"X",(0,0,0),font=font)
draw.text((1400, 1450),"X",(0,0,0),font=font)
draw.text((1480, 1450),"X",(0,0,0),font=font)

#Signature
draw.text((1200, 1770),"X",(0,0,0),font=font)

#Todays date
#day
draw.text((1110, 2170),"X",(0,0,0),font=font)
draw.text((1150, 2170),"X",(0,0,0),font=font)
#month
draw.text((1210, 2170),"X",(0,0,0),font=font)
draw.text((1250, 2170),"X",(0,0,0),font=font)
#year
draw.text((1315, 2170),"X",(0,0,0),font=font)
draw.text((1355, 2170),"X",(0,0,0),font=font)
draw.text((1390, 2170),"X",(0,0,0),font=font)
draw.text((1430, 2170),"X",(0,0,0),font=font)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1654x2339 at 0x12BED8358>

# %%
jpeg_dict={}
counter=0

# %%
responses=pd.read_csv('sample_responses.csv')

# %%
responses.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
for row in responses.index:
    
    jpeg_dict[row] = Image.open("form.jpg")
    draw = ImageDraw.Draw(jpeg_dict[counter])

    #First name(s) in full
    draw.text((150, 695),"X",(0,0,0),font=font) 

    #Surname
    draw.text((150, 580),"X",(0,0,0),font=font) 

    #home_address
    draw.text((150, 810),"X",(0,0,0),font=font) 
    draw.text((150, 870),"X",(0,0,0),font=font) 
    draw.text((150, 930),"X",(0,0,0),font=font)

    #postcode
    draw.text((550, 980),"X",(0,0,0),font=font)

    #Telephone
    draw.text((150, 1095),"X",(0,0,0),font=font) 

    #Email
    draw.text((150, 1210),"X",(0,0,0),font=font) 

    #Until further notice
    draw.text((133, 1600),"X",(0,0,0),font=font) 

    #Address for ballot paper
    draw.text((950, 620),"X",(0,0,0),font=font) 
    draw.text((950, 680),"X",(0,0,0),font=font)
    draw.text((950, 730),"X",(0,0,0),font=font)

    #Postcode
    draw.text((1430, 790),"X",(0,0,0),font=font)

    #Reason 
    draw.text((950, 930),"X",(0,0,0),font=font)
    draw.text((950, 990),"X",(0,0,0),font=font)

    #Date of birth
    #day
    draw.text((930, 1450),"X",(0,0,0),font=font) 
    draw.text((995, 1450),"X",(0,0,0),font=font)
    #month
    draw.text((1100, 1450),"X",(0,0,0),font=font) 
    draw.text((1165, 1450),"X",(0,0,0),font=font) 
    #year
    draw.text((1270, 1450),"X",(0,0,0),font=font)
    draw.text((1340, 1450),"X",(0,0,0),font=font)
    draw.text((1400, 1450),"X",(0,0,0),font=font)
    draw.text((1480, 1450),"X",(0,0,0),font=font)

    #Signature
    draw.text((1200, 1770),"X",(0,0,0),font=font)

    #Todays date
    #day
    draw.text((1110, 2170),"X",(0,0,0),font=font)
    draw.text((1150, 2170),"X",(0,0,0),font=font)
    #month
    draw.text((1210, 2170),"X",(0,0,0),font=font)
    draw.text((1250, 2170),"X",(0,0,0),font=font)
    #year
    draw.text((1315, 2170),"X",(0,0,0),font=font)
    draw.text((1355, 2170),"X",(0,0,0),font=font)
    draw.text((1390, 2170),"X",(0,0,0),font=font)
    draw.text((1430, 2170),"X",(0,0,0),font=font)

# %%
jpeg_dict[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-356-b7c4f1a1fd23> in <module>
# ----> 1 jpeg_dict[2]
#
# KeyError: 2
